# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.transforms import Compose, ToTensor, Normalize
from torchvision.datasets import CIFAR10
import numpy as np
from torch.optim.optimizer import Optimizer
from torchvision.utils import make_grid, save_image
from tqdm import tqdm
import matplotlib.pyplot as plt

# %%
# !pip install pytest-cov

# %% [markdown]
# **Задание 1** Запускаем тесты, смотрим покрытие. Отчет о поиске и исправлении багов.

# %%
# !pytest --cov=/content/homework tests/
# Out:
# ======================================= test session starts ========================================
# platform linux -- Python 3.11.11, pytest-8.3.5, pluggy-1.5.0
# rootdir: /content/homework
# plugins: cov-6.0.0, langsmith-0.3.11, typeguard-4.4.2, anyio-3.7.1
# collected 9 items
#
# tests/test_model.py .....                                                                    [ 55%]
# tests/test_pipeline.py ....                                                                  [100%]
#
# ---------- coverage: platform linux, python 3.11.11-final-0 ----------
# Name                     Stmts   Miss  Cover
# --------------------------------------------
# main.py                     20     20     0%
# modeling/__init__.py         0      0   100%
# modeling/diffusion.py       33      0   100%
# modeling/training.py        35      0   100%
# modeling/unet.py            68      0   100%
# tests/__init__.py            0      0   100%
# tests/test_model.py         22      0   100%
# ...

# %% [markdown]
# **Задание 2.**

# %%
# !unzip /content/efficient-dl-systems-main.zip
# Out:
# Archive:  /content/efficient-dl-systems-main.zip
#    creating: efficient-dl-systems-main/
#    creating: efficient-dl-systems-main/week02_management_and_testing/
#   inflating: efficient-dl-systems-main/week02_management_and_testing/lecture.pdf
#   inflating: efficient-dl-systems-main/week02_management_and_testing/README.md
#    creating: efficient-dl-systems-main/week02_management_and_testing/homework_tasks12/
#   inflating: efficient-dl-systems-main/week02_management_and_testing/homework_tasks12/requirements.txt
#    creating: efficient-dl-systems-main/week02_management_and_testing/homework_tasks12/.ipynb_checkpoints/
#   inflating: efficient-dl-systems-main/week02_management_and_testing/homework_tasks12/.ipynb_checkpoints/hparams-checkpoint.py
#   inflating: efficient-dl-systems-main/week02_management_and_testing/homework_tasks12/.ipynb_checkpoints/main-checkpoint.py
#   inflating: efficient-dl-systems-main/week02_management_and_testing/homework_tasks12/main.py
# ...

# %%
# %cd /content/efficient-dl-systems-main/week02_management_and_testing/homework_tasks12
# Out:
# /content/efficient-dl-systems-main/week02_management_and_testing/homework_tasks12

# %%
# !uv init .
# Out:
# error: Project is already initialized in `/content/homework_tasks12` (`pyproject.toml` file exists)

# %%
# !pytest -vvv tests/test_model.py

# %%
# !pip install uv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.2/16.2 MB 91.7 MB/s eta 0:00:00
# ...

# %%
# !pytest -vvv tests/test_model.py

# %%
# !pytest -vvv tests/test_pipeline.py
# Out:
# ======================================= test session starts ========================================
# platform linux -- Python 3.11.11, pytest-8.3.4, pluggy-1.5.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/homework
# plugins: cov-6.0.0, typeguard-4.4.2, anyio-3.7.1, langsmith-0.3.11
# collected 2 items
#
# tests/test_pipeline.py::test_train_on_one_batch[cpu] PASSED                                  [ 50%]
# tests/test_pipeline.py::test_training[cpu] FAILED                                            [100%]
#
# ============================================= FAILURES =============================================
# ________________________________________ test_training[cpu] ________________________________________
#
# device = 'cpu'
# train_dataset = Dataset CIFAR10
#     Number of datapoints: 50000
#     Root location: ./data
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                ToTensor()
# ...

# %%
# !python prepare_data.py
# Out:
# 100% 170M/170M [00:05<00:00, 29.4MB/s]

# %%
# !uv lock
# Out:
# Using CPython 3.11.11 interpreter at: /usr/bin/python3
# Resolved 130 packages in 4.13s

# %%
# !uv pip install dvc
# Out:
# Using Python 3.11.11 environment at: /usr
# Resolved 97 packages in 103ms
#    Building antlr4-python3-runtime==4.9.3
#    Building antlr4-python3-runtime==4.9.3
# ⠙ Preparing packages... (0/45)
#    Building antlr4-python3-runtime==4.9.3
# ⠙ Preparing packages... (0/45)
# configobj  ------------------------------     0 B/34.78 KiB
#    Building antlr4-python3-runtime==4.9.3
# ⠙ Preparing packages... (0/45)
# pathspec   ------------------------------     0 B/30.46 KiB
# configobj  ------------------------------     0 B/34.78 KiB
#    Building antlr4-python3-runtime==4.9.3
# ⠙ Preparing packages... (0/45)
# semver     ------------------------------     0 B/17.49 KiB
# pathspec   ------------------------------     0 B/30.46 KiB
# configobj  ------------------------------     0 B/34.78 KiB
#    Building antlr4-python3-runtime==4.9.3
# ⠙ Preparing packages... (0/45)
# dictdiffer ------------------------------     0 B/16.36 KiB
# ...

# %%
# !dvc init
# Out:
# ERROR: failed to initiate DVC - /content/efficient-dl-systems-main/week02_management_and_testing/homework_tasks12 is not tracked by any supported SCM tool (e.g. Git). Use `--no-scm` if you don't want to use any SCM or `--subdir` if initializing inside a subdirectory of a parent SCM repository.

# %%
# !dvc repro --dry
# Out:
# Running stage 'prepare_data':
# > python prepare_data.py
#
# Running stage 'train':
# > python main.py
# Use `dvc push` to send your updates to remote storage.

# %%
# !dvc remote add -d my_project https://github.com/zangezy84/dvc
# Out:
# Setting 'my_project' as a default remote.
# ERROR: configuration error - config file error: remote 'my_project' already exists. Use `-f|--force` to overwrite it.

# %%
# !dvc push
# Out:
# ...
# Pushing
# Everything is up to date.

# %%
# !unzip "homework_upd.zip"
# Out:
# Archive:  homework_upd.zip
#    creating: homework_upd/
#   inflating: homework_upd/requirements.txt
#   inflating: homework_upd/main.py
#    creating: homework_upd/tests/
#   inflating: homework_upd/tests/test_pipeline.py
#   inflating: homework_upd/tests/test_model.py
#  extracting: homework_upd/tests/__init__.py
#    creating: homework_upd/modeling/
#  extracting: homework_upd/modeling/__init__.py
#   inflating: homework_upd/modeling/diffusion.py
#   inflating: homework_upd/modeling/unet.py
#   inflating: homework_upd/modeling/training.py
#   inflating: homework_upd/README.md

# %%
samples = generate_samples(ddpm, device, "samples/1.png")

# %%
import pathlib
pathlib.Path("images/samples.jpg").exists()
# Out:
# True

# %%
samples.shape == torch.Size([8, 3, 32, 32])
# Out:
# True

# %%
# !zip -r /homework.zip /content/homework
